# %%
import pandas as pd

# %%
df = pd.read_csv("/content/House Prediction Data(Same+Distributed) - Sheet1.csv")

# %%
df.columns
# Out:
# Index(['Area Values', 'Price (in Lakh)'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Area Values        0
# Price (in Lakh)    0
# dtype: int64

# %%
df
# Out:
#     Area Values  Price (in Lakh)
# 0           500               20
# 1           550               25
# 2           600               30
# 3           650               35
# 4           700               40
# 5           750               45
# 6           800               50
# 7           850               55
# 8           900               60
# 9           950               65
# 10         1000               70
# 11          230               13
# 12          220               25
# 13          454               14
# 14          334               26
# 15          556               15
# 16          776               27
# 17          121               87
# 18          454               56
# 19          776               44
# 20          998               66
# 21          787               33
# 22          726               98
# 23          908               71
# 24          907               41
# 25          905               61
# 26          670               78
# 27          876               55
# 28          453               90
# 29          232               11
# 30          459               19
# 31          231               73
# 32          565               65
# 33          767               39
# 34          773               94
# 35          355               61
# 36          916               80
# 37          845               22
# 38          344               51

# %%
df.shape
# Out:
# (39, 2)

# %%
x=df['Area Values']
y=df['Price (in Lakh)']

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,0:1].values #ILOC IS USED JABH APAN KO PERTICULR DATASET KE COLUMNS KO ACCESS KRNA HAI TABH

# %%
x
# Out:
# array([[ 500],
#        [ 550],
#        [ 600],
#        [ 650],
#        [ 700],
#        [ 750],
#        [ 800],
#        [ 850],
#        [ 900],
#        [ 950],
#        [1000],
#        [ 230],
#        [ 220],
#        [ 454],
#        [ 334],
#        [ 556],
#        [ 776],
#        [ 121],
#        [ 454],
#        [ 776],
#        [ 998],
#        [ 787],
#        [ 726],
#        [ 908],
#        [ 907],
#        [ 905],
#        [ 670],
#        [ 876],
#        [ 453],
#        [ 232],
#        [ 459],
#        [ 231],
#        [ 565],
#        [ 767],
#        [ 773],
#        [ 355],
#        [ 916],
#        [ 845],
#        [ 344]])

# %%
y = df.iloc[:,-1].values

# %%
y
# Out:
# array([20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 13, 25, 14, 26, 15, 27,
#        87, 56, 44, 66, 33, 98, 71, 41, 61, 78, 55, 90, 11, 19, 73, 65, 39,
#        94, 61, 80, 22, 51])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()  #here regressor is the object of this model

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([35.33143035, 43.44780219, 55.59184727, 42.37985853, 38.9624388 ,
#        52.81519375, 52.60160502, 45.58368952, 35.63655711, 48.81803318,
#        35.97219655, 48.72649515])

# %%
from sklearn.metrics import r2_score, classification_report

# %%
r2_score(y_test, y_pred)
# Out:
# -0.48141469542292303

# %%
y_value = regressor.predict([[344]])

# %%
y_value
# Out:
# array([32.21913739])
